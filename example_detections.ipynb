# %% [markdown]
# # Comprehensive earthquake catalog for Colombia
#
# ## This notebook displays the ongoing process of building a coprehensive earthquake catalog  for Colombia based on deep learning.

# %%
from IPython import display

# %% [markdown]
# Approximately 8000 earthquakes detected at station BAR2 in the Eastern Cordillera of Colombia during 2015

# %%
display.Image('../BAR2_extractions/BAR2_matrix.png')

# %%
display.Image('../histcumfigures/BAR2_2015_histcum.png')

# %%
display.Image('../histcumfigures/BAR2_2016_histcum.png')
